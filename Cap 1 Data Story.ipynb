# %% [markdown]
# After exploring this data set I was able to identify some of the key features that cause a higher sale price.

# %%
# %matplotlib inline
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
pd.set_option('display.max_columns', 500)

# %%
cd C:\Users\Anthony.Sledge\Desktop\Code\Cap_1\Data
# Out:
# C:\Users\Anthony.Sledge\Desktop\Code\Cap_1\Data

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Anthony.Sledge\\Desktop\\Code\\Cap_1\\Data'

# %%
houses= pd.DataFrame.from_csv ('train.csv')
houses.head(100)
# Out:
#      MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1            60       RL         65.0     8450   Pave   NaN      Reg
# 2            20       RL         80.0     9600   Pave   NaN      Reg
# 3            60       RL         68.0    11250   Pave   NaN      IR1
# 4            70       RL         60.0     9550   Pave   NaN      IR1
# 5            60       RL         84.0    14260   Pave   NaN      IR1
# 6            50       RL         85.0    14115   Pave   NaN      IR1
# 7            20       RL         75.0    10084   Pave   NaN      Reg
# 8            60       RL          NaN    10382   Pave   NaN      IR1
# 9            50       RM         51.0     6120   Pave   NaN      Reg
# 10          190       RL         50.0     7420   Pave   NaN      Reg
# 11           20       RL         70.0    11200   Pave   NaN      Reg
# 12           60       RL         85.0    11924   Pave   NaN      IR1
# ...

# %%
plt.hist(houses.YrSold.dropna(),bins=10)
# Out:
# (array([ 314.,    0.,  329.,    0.,    0.,  304.,    0.,  338.,    0.,  175.]),
#  array([ 2006. ,  2006.4,  2006.8,  2007.2,  2007.6,  2008. ,  2008.4,
#          2008.8,  2009.2,  2009.6,  2010. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# I started by getting a general understanding of the what sale prices I had within the dataset. I noticed that I have more middle class priced houses by plotting them on a histogram. I noticed a few large outliers.

# %%
plt.hist(houses.SalePrice.dropna(),bins=40)
# Out:
# (array([   7.,   15.,   53.,   73.,  153.,  227.,  188.,  155.,  141.,
#           88.,   78.,   66.,   44.,   42.,   20.,   29.,   20.,    8.,
#           10.,   13.,    7.,    5.,    4.,    3.,    1.,    2.,    0.,
#            1.,    2.,    0.,    1.,    0.,    2.,    0.,    0.,    0.,
#            0.,    0.,    0.,    2.]),
#  array([  34900. ,   52902.5,   70905. ,   88907.5,  106910. ,  124912.5,
#          142915. ,  160917.5,  178920. ,  196922.5,  214925. ,  232927.5,
#          250930. ,  268932.5,  286935. ,  304937.5,  322940. ,  340942.5,
#          358945. ,  376947.5,  394950. ,  412952.5,  430955. ,  448957.5,
#          466960. ,  484962.5,  502965. ,  520967.5,  538970. ,  556972.5,
#          574975. ,  592977.5,  610980. ,  628982.5,  646985. ,  664987.5,
#          682990. ,  700992.5,  718995. ,  736997.5,  755000. ]),
#  <a list of 40 Patch objects>)

# %% [markdown]
# I then wanted to see in what neighborhoods a majority of the houses were in my dataset and their average sale price.

# %%
houses.Neighborhood.value_counts()
# Out:
# NAmes      225
# CollgCr    150
# OldTown    113
# Edwards    100
# Somerst     86
# Gilbert     79
# NridgHt     77
# Sawyer      74
# NWAmes      73
# SawyerW     59
# BrkSide     58
# Crawfor     51
# Mitchel     49
# NoRidge     41
# Timber      38
# IDOTRR      37
# ClearCr     28
# SWISU       25
# StoneBr     25
# Blmngtn     17
# MeadowV     17
# BrDale      16
# Veenker     11
# NPkVill      9
# Blueste      2
# Name: Neighborhood, dtype: int64

# %%
hood_index = houses.set_index(['Neighborhood'])
hood_index.head()
# Out:
#               MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Neighborhood
# CollgCr               60       RL         65.0     8450   Pave   NaN      Reg
# Veenker               20       RL         80.0     9600   Pave   NaN      Reg
# CollgCr               60       RL         68.0    11250   Pave   NaN      IR1
# Crawfor               70       RL         60.0     9550   Pave   NaN      IR1
# NoRidge               60       RL         84.0    14260   Pave   NaN      IR1
#
#              LandContour Utilities LotConfig LandSlope Condition1 Condition2  \
# Neighborhood
# CollgCr              Lvl    AllPub    Inside       Gtl       Norm       Norm
# Veenker              Lvl    AllPub       FR2       Gtl      Feedr       Norm
# CollgCr              Lvl    AllPub    Inside       Gtl       Norm       Norm
# Crawfor              Lvl    AllPub    Corner       Gtl       Norm       Norm
# NoRidge              Lvl    AllPub       FR2       Gtl       Norm       Norm
#
# ...

# %%
houses.groupby('Neighborhood').SalePrice.mean().sort_values(ascending=False).plot(kind='bar')

# %% [markdown]
# I analyzed other features such as overall quality of the house and types of sales.

# %%
houses.groupby('SaleCondition').SalePrice.mean().sort_values(ascending=False).plot(kind='bar')

# %%
houses.groupby('OverallQual').SalePrice.mean().sort_values(ascending=False).plot(kind='bar')

# %% [markdown]
# I then looked to see how the prices were changing over time.

# %%
houses.groupby('YrSold').SalePrice.mean().sort_values(ascending=False).plot()

# %% [markdown]
# Other factors such as Lot Configuration (Cul De Sac, corner lot, inside lot, etc.), outside exterior,  and garage type, played a bigger roll than I expected.

# %%
houses.groupby('LotConfig').SalePrice.mean().sort_values(ascending=False).plot()

# %%
houses.groupby('KitchenQual').SalePrice.mean().sort_values(ascending=False).plot(kind='bar')

# %%
houses.groupby('Exterior1st').SalePrice.mean().sort_values(ascending=False).plot(kind='bar')

# %%
houses.groupby('Functional').SalePrice.mean().sort_values(ascending=False).plot(kind='bar')

# %%
houses.groupby('GarageType').SalePrice.mean().sort_values(ascending=False).plot()

# %%
sns.boxplot(houses.GrLivArea.dropna())

# %% [markdown]
# I then did a boxplot and kde plot to get a better understanding of the distribution of sale prices. In the future when I am modeling it will be nice to know what range I should be landing within.

# %%
sns.kdeplot(houses.SalePrice)
# Out:
# C:\Users\Anthony.Sledge\AppData\Local\Continuum\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
sns.distplot(houses.SalePrice)
# Out:
# C:\Users\Anthony.Sledge\AppData\Local\Continuum\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %% [markdown]
# I noticed some obvious correlations such as neighborhoods and living area affecting prices. I think once I learn how to quantify each feature that determining the sale price will be possible with all the data I have. I have quite a few NAs, however when there is an NA it is usually for the entire column and not sporadically through each.
